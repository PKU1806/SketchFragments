# %%
# -*- coding: UTF-8 -*-
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

plt.rc('font', family='Times New Roman')

# %%
# FE - ARE

x_axix = np.array([16*i for i in range(2,12)])
# x_axix[0] = 50

res = [[] for i in range(3)]

#开始画图
plt.figure(figsize=(6, 4.5))
# plt.title('Frequency Estimation', fontsize = 13)
# plt.xlim( 2**(2.5),  2**13.5 )
plt.xscale('linear')
plt.yscale('linear')
plt.tick_params(labelsize = 20)

with open('../log/log_fe_mininet10k') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        res[cnt % 3].append(data[1]) # are
        cnt += 1
        #if cnt > 3000:
        #    break

x_axix = x_axix
plt.plot(x_axix, res[0], label='Half CU(ours)', linestyle='-', marker='s', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[1], label='CM Sketch', linestyle='-', marker='^', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[2], label='CU Sketch', linestyle='-', marker='v', markerfacecolor='none', alpha = 0.6)
# plt.plot(x_axix, res[7], label='Heavy-Guardian', linestyle='-', marker='x', alpha = 0.8)
plt.legend(loc = 'upper right', fontsize = 19) # 显示图例

plt.grid(True, linestyle='--', axis='y')

print(plt.ylim())
# plt.ylim(top=2500)
plt.xlabel('Number of Bucket', fontsize = 26)
plt.ylabel('ARE', fontsize = 26)
plt.tight_layout()
plt.savefig('fe_are_mininet10k.png', ppi=400)
plt.show()
#python 一个折线图绘制多个曲线
# Out:
# (-0.16193186084999997, 3.40576818385)

# %%
# FE - ARE

x_axix = np.array([16*i for i in range(2,12)])
# x_axix[0] = 50

res = [[] for i in range(3)]

#开始画图
plt.figure(figsize=(6, 4.5))
# plt.title('Frequency Estimation', fontsize = 13)
# plt.xlim( 2**(2.5),  2**13.5 )
plt.xscale('linear')
plt.yscale('linear')
plt.tick_params(labelsize = 20)

with open('../log/log_fe_mininet10k') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        res[cnt % 3].append(data[3]) # are
        cnt += 1
        #if cnt > 3000:
        #    break

x_axix = x_axix
plt.plot(x_axix, res[0], label='Half CU(ours)', linestyle='-', marker='s', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[1], label='CM Sketch', linestyle='-', marker='^', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[2], label='CU Sketch', linestyle='-', marker='v', markerfacecolor='none', alpha = 0.6)
# plt.plot(x_axix, res[7], label='Heavy-Guardian', linestyle='-', marker='x', alpha = 0.8)
plt.legend(loc = 'upper right', fontsize = 19) # 显示图例

plt.grid(True, linestyle='--', axis='y')

print(plt.ylim())
# plt.ylim(top=2500)
plt.xlabel('Number of Bucket', fontsize = 26)
plt.ylabel('AAE', fontsize = 26)
plt.tight_layout()
plt.savefig('fe_aae_mininet10k.png', ppi=400)
plt.show()
#python 一个折线图绘制多个曲线
# Out:
# (-4.256453095, 90.80486919500001)

# %%
# BH - PR

x_axix = np.array([4096*i*3/250 for i in range(1,17)])
# x_axix[0] = 50

res = [[] for i in range(5)]

#开始画图
plt.figure(figsize=(6, 4.5))
# plt.title('Frequency Estimation', fontsize = 13)
# plt.xlim( 2**(2.5),  2**13.5 )
plt.xscale('linear')
plt.yscale('linear')
plt.tick_params(labelsize = 20)

with open('../log/log_bh_100k_0.9') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[0].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_bh_100k_0.7') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[1].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break


with open('../log/log_bh_100k_0.5') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[2].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_bh_100k_0.3') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[3].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_bh_100k_0.1') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[4].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break   
   
print(len(x_axix), len(res[0]))
x_axix = x_axix
plt.plot(x_axix, res[0], label='threshold=0.9', linestyle='-', marker='s', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[1], label='threshold=0.7', linestyle='-', marker='^', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[2], label='threshold=0.5', linestyle='-', marker='v', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[3], label='threshold=0.3', linestyle='-', marker='x', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[4], label='threshold=0.1', linestyle='-', marker='o', markerfacecolor='none', alpha = 0.6)
# plt.plot(x_axix, res[7], label='Heavy-Guardian', linestyle='-', marker='x', alpha = 0.8)
plt.legend(loc = 'upper left', fontsize = 19) # 显示图例
with open('../log/log_bh_pr.csv', 'w') as f:
    f.write(','.join([str(x) for x in x_axix[1::2]]) + '\n')
    for i in range(5):
        f.write(','.join([str(x) for x in res[i][1::2]]) + '\n')

plt.grid(True, linestyle='--', axis='y')

print(plt.ylim())
plt.ylim(top=2.2)
plt.xlabel('Memory Size(KB)', fontsize = 26)
plt.ylabel('Precision Rate', fontsize = 26)
plt.tight_layout()
plt.savefig('bh_100k_pr.pdf')
plt.show()
#python 一个折线图绘制多个曲线
# Out:
# 16 16
# (0.2903488, 1.0303452)

# %%
# BH - RR

x_axix = np.array([4096*i*3/250 for i in range(1,17)])
# x_axix[0] = 50

res = [[] for i in range(5)]

#开始画图
plt.figure(figsize=(6, 4.5))
# plt.title('Frequency Estimation', fontsize = 13)
# plt.xlim( 2**(2.5),  2**13.5 )
plt.xscale('linear')
plt.yscale('linear')
plt.tick_params(labelsize = 20)

with open('../log/log_bh_100k_0.9') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[0].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_bh_100k_0.7') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[1].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break


with open('../log/log_bh_100k_0.5') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[2].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_bh_100k_0.3') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[3].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_bh_100k_0.1') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[4].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break   

print(len(x_axix), len(res[0]))
x_axix = x_axix
plt.plot(x_axix, res[0], label='threshold=0.9', linestyle='-', marker='s', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[1], label='threshold=0.7', linestyle='-', marker='^', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[2], label='threshold=0.5', linestyle='-', marker='v', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[3], label='threshold=0.3', linestyle='-', marker='x', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[4], label='threshold=0.1', linestyle='-', marker='o', markerfacecolor='none', alpha = 0.6)
# plt.plot(x_axix, res[7], label='Heavy-Guardian', linestyle='-', marker='x', alpha = 0.8)
plt.legend(loc = 'upper left', fontsize = 19) # 显示图例
with open('../log/log_bh_rr.csv', 'w') as f:
    f.write(','.join([str(x) for x in x_axix[1::2]]) + '\n')
    for i in range(5):
        f.write(','.join([str(x) for x in res[i][1::2]]) + '\n')

plt.grid(True, linestyle='--', axis='y')

print(plt.ylim())
plt.ylim(top=1.6)
plt.xlabel('Memory Size(KB)', fontsize = 26)
plt.ylabel('Recall Rate', fontsize = 26)
plt.tight_layout()
plt.savefig('bh_100k_rr.pdf')
plt.show()
#python 一个折线图绘制多个曲线
# Out:
# 16 16
# (0.6564184, 1.0155376)

# %%
# LP - PR

x_axix = np.array([4096*i*3/250 for i in range(1,17)])
# x_axix[0] = 50

res = [[] for i in range(4)]

#开始画图
plt.figure(figsize=(6, 4.5))
# plt.title('Frequency Estimation', fontsize = 13)
# plt.xlim( 2**(2.5),  2**13.5 )
plt.xscale('linear')
plt.yscale('linear')
plt.tick_params(labelsize = 20)

with open('../log/log_lp_100k_3.0') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[0].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_lp_100k_5.0') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[1].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break


with open('../log/log_lp_100k_7.0') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[2].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_lp_100k_9.0') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[3].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break
   
print(len(x_axix), len(res[0]))
x_axix = x_axix
plt.plot(x_axix, res[0], label='threshold=3', linestyle='-', marker='s', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[1], label='threshold=5', linestyle='-', marker='^', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[2], label='threshold=7', linestyle='-', marker='v', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[3], label='threshold=9', linestyle='-', marker='x', markerfacecolor='none', alpha = 0.6)
# plt.plot(x_axix, res[7], label='Heavy-Guardian', linestyle='-', marker='x', alpha = 0.8)
plt.legend(loc = 'upper left', fontsize = 14) # 显示图例
# with open('../log/log_pr.csv', 'w') as f:
#     for i in range(4):
#         f.write(','.join([str(x) for x in res[i]]) + '\n')

plt.grid(True, linestyle='--', axis='y')

print(plt.ylim())
plt.ylim(top=1.3)
plt.xlabel('Memory Size(KB)', fontsize = 26)
plt.ylabel('Precision Rate', fontsize = 26)
plt.tight_layout()
plt.savefig('lp_100k_pr.pdf')
plt.show()

with open('../log/log_lp_pr.csv', 'w') as f:
    f.write(','.join([str(x) for x in x_axix[1::2]]) + '\n')
    for i in range(4):
        f.write(','.join([str(x) for x in res[i][1::2]]) + '\n')
#python 一个折线图绘制多个曲线
# Out:
# 16 16
# (0.37584660000000003, 1.0231174)

# %%
# LP - RR

x_axix = np.array([4096*i*3/250 for i in range(1,17)])
# x_axix[0] = 50

res = [[] for i in range(4)]

#开始画图
plt.figure(figsize=(6, 4.5))
# plt.title('Frequency Estimation', fontsize = 13)
# plt.xlim( 2**(2.5),  2**13.5 )
plt.xscale('linear')
plt.yscale('linear')
plt.tick_params(labelsize = 20)

with open('../log/log_lp_100k_3.0') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[0].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_lp_100k_5.0') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[1].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break


with open('../log/log_lp_100k_7.0') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[2].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_lp_100k_9.0') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 3 == 0:
            res[3].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break
   
print(len(x_axix), len(res[0]))
x_axix = x_axix
plt.plot(x_axix, res[0], label='threshold=3', linestyle='-', marker='s', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[1], label='threshold=5', linestyle='-', marker='^', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[2], label='threshold=7', linestyle='-', marker='v', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[3], label='threshold=9', linestyle='-', marker='x', markerfacecolor='none', alpha = 0.6)
# plt.plot(x_axix, res[7], label='Heavy-Guardian', linestyle='-', marker='x', alpha = 0.8)
plt.legend(loc = 'upper left', fontsize = 14) # 显示图例
# with open('../log/log_pr.csv', 'w') as f:
#     for i in range(4):
#         f.write(','.join([str(x) for x in res[i]]) + '\n')

plt.grid(True, linestyle='--', axis='y')

print(plt.ylim())
plt.ylim(top=1.3)
plt.xlabel('Memory Size(KB)', fontsize = 26)
plt.ylabel('Recall Rate', fontsize = 26)
plt.tight_layout()
plt.savefig('lp_100k_rr.pdf', ppi=400)
plt.show()


with open('../log/log_lp_rr.csv', 'w') as f:
    f.write(','.join([str(x) for x in x_axix[1::2]]) + '\n')
    for i in range(4):
        f.write(','.join([str(x) for x in res[i][1::2]]) + '\n')
print(plt.ylim())

#python 一个折线图绘制多个曲线
# Out:
# 16 16
# (0.47715280000000004, 1.0230652)
# (0.0, 1.0)

# %%
# IT - PR

x_axix = np.array([512*i*3/250 for i in range(1,9)])
# x_axix[0] = 50

res = [[] for i in range(4)]

#开始画图
plt.figure(figsize=(6, 4.5))
# plt.title('Frequency Estimation', fontsize = 13)
# plt.xlim( 2**(2.5),  2**13.5 )
plt.xscale('linear')
plt.yscale('linear')
plt.tick_params(labelsize = 20)

with open('../log/log_it_10k_1.3') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 1 == 0:
            res[0].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_it_10k_1.5') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 1 == 0:
            res[1].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break


with open('../log/log_it_10k_1.7') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 1 == 0:
            res[2].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_it_10k_1.9') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 1 == 0:
            res[3].append(data[0]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break
   
print(len(x_axix), len(res[0]))
x_axix = x_axix
plt.plot(x_axix, res[0], label='threshold=1.3', linestyle='-', marker='s', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[1], label='threshold=1.5', linestyle='-', marker='^', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[2], label='threshold=1.7', linestyle='-', marker='v', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[3], label='threshold=1.9', linestyle='-', marker='x', markerfacecolor='none', alpha = 0.6)
# plt.plot(x_axix, res[7], label='Heavy-Guardian', linestyle='-', marker='x', alpha = 0.8)
plt.legend(loc = 'upper left', fontsize = 14) # 显示图例
# with open('../log/log_pr.csv', 'w') as f:
#     for i in range(4):
#         f.write(','.join([str(x) for x in res[i]]) + '\n')

plt.grid(True, linestyle='--', axis='y')

print(plt.ylim())
plt.ylim(top=1.3)
plt.xlabel('Memory Size(KB)', fontsize = 26)
plt.ylabel('Precision Rate', fontsize = 26)
plt.tight_layout()
plt.savefig('it_10k_pr.pdf')
plt.show()

with open('../log/log_it_pr.csv', 'w') as f:
    f.write(','.join([str(x) for x in x_axix]) + '\n')
    for i in range(4):
        f.write(','.join([str(x) for x in res[i]]) + '\n')
#python 一个折线图绘制多个曲线
# Out:
# 8 8
# (0.7621737, 1.0105383000000001)

# %%
# IT - RR

x_axix = np.array([512*i*3/250 for i in range(1,9)])
# x_axix[0] = 50

res = [[] for i in range(4)]

#开始画图
plt.figure(figsize=(6, 4.5))
# plt.title('Frequency Estimation', fontsize = 13)
# plt.xlim( 2**(2.5),  2**13.5 )
plt.xscale('linear')
plt.yscale('linear')
plt.tick_params(labelsize = 20)

with open('../log/log_it_10k_1.3') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 1 == 0:
            res[0].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_it_10k_1.5') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 1 == 0:
            res[1].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break


with open('../log/log_it_10k_1.7') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 1 == 0:
            res[2].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break

        
with open('../log/log_it_10k_1.9') as f:
    cnt = 0
    for line in f:
        data = [float(x) for x in line.split()]
        if cnt % 1 == 0:
            res[3].append(data[1]) # pr
        cnt += 1
        #if cnt > 3000:
        #    break
   
print(len(x_axix), len(res[0]))
x_axix = x_axix
plt.plot(x_axix, res[0], label='threshold=1.3', linestyle='-', marker='s', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[1], label='threshold=1.5', linestyle='-', marker='^', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[2], label='threshold=1.7', linestyle='-', marker='v', markerfacecolor='none', alpha = 0.6)
plt.plot(x_axix, res[3], label='threshold=1.9', linestyle='-', marker='x', markerfacecolor='none', alpha = 0.6)
# plt.plot(x_axix, res[7], label='Heavy-Guardian', linestyle='-', marker='x', alpha = 0.8)
plt.legend(loc = 'upper left', fontsize = 14) # 显示图例
# with open('../log/log_pr.csv', 'w') as f:
#     for i in range(4):
#         f.write(','.join([str(x) for x in res[i]]) + '\n')

plt.grid(True, linestyle='--', axis='y')

print(plt.ylim())
plt.ylim(top=1.3)
plt.xlabel('Memory Size(KB)', fontsize = 26)
plt.ylabel('Recall Rate', fontsize = 26)
plt.tight_layout()
plt.savefig('it_10k_rr.pdf')
plt.show()

with open('../log/log_it_rr.csv', 'w') as f:
    f.write(','.join([str(x) for x in x_axix]) + '\n')
    for i in range(4):
        f.write(','.join([str(x) for x in res[i]]) + '\n')
#python 一个折线图绘制多个曲线
# Out:
# 8 8
# (0.665933, 1.014677)
